# %% [markdown]
# # Weekend Planner Agent Demo
#
# This notebook demonstrates how to use `planner_agent` to create a weekend plan using LangChain + Multi-Agent AI.

# %%
import os, sys
sys.path.append(os.path.abspath("."))  # Ensures the current directory is on the path

# %%
from agents.planner_agent import plan_weekend

plan_weekend("Plan a fun weekend with outdoor activities, food, and art events")
# Out:
# Planning weekend based on preferences: Plan a fun weekend with outdoor activities, food, and art events
# {'day': 'Saturday', 'type': 'Art'}
